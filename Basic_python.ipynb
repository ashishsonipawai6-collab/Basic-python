# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishsonipawai6-collab/Basic-python/blob/main/Basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ashish")
# Out:
# Ashish

# %%
print("my name is Ashish")
print("my age is 19")
# Out:
# my name is Ashish
# my age is 19

# %%
# use in (,) print in single line
print("my name is Ashish , my age is 19")
# Out:
# my name is Ashish , my age is 19

# %%
print(39)
# Out:
# 39

# %%
#  sum variable
print(25+45)
# Out:
# 70

# %%
name = "Ashish"
age = 19
weight = 50
print("name")
# Out:
# name

# %%
name = "Ashish"
age = 19
weight = 50
print("my name is :", name)
print("my weight is :", weight)
print("my age is :", age)
# Out:
# my name is : Ashish
# my weight is : 50
# my age is : 19

# %%
# age2 = age
name = "Ashish"
age = 19
weight = 50
age2 = age
print(age2)
# Out:
# 19

# %%
# type find out
name = "Ashish"
age = 19
weight = 50.5
print(type(name))
print(type(age))
print(type(weight))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
# bool & None
age = 19
old = False
age = None
print(type(age))
# Out:
# <class 'NoneType'>

# %%
print(type(old))
# Out:
# <class 'bool'>

# %%
# print sum and diff
a = 40
b = 20
sum = a + b
print(sum)
# Out:
# 60

# %%
diff = a - b
print(diff)
# Out:
# 20

# %%
# arithmatic operators
a = 5
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 9
# 1
# 20
# 1.25

# %%
# remainder
print(a % b)
# Out:
# 1

# %%
# a^b
print(a ** b)
# Out:
# 625

# %%
# Relation operator
a = 50
b = 20
print( a == b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %%
print(a >= b)
# Out:
# True

# %%
print(a <= b)
# Out:
# False

# %%
# Assignment operator
num = 10
num += 10
print(num)
# Out:
# 20

# %%
num = 20
num -= 10
print(num)
# Out:
# 10

# %%
num = 20
num *= 10
print(num)
# Out:
# 200

# %%
num = 20
num /= 10
print(num)
# Out:
# 2.0

# %%
num = 20
num %= 10
print(num)
# Out:
# 0

# %%
num = 20
num **= 2
print(num)
# Out:
# 400

# %%
# Logical Operator(not , or , and)
a = 50
b = 30
print(not True )
print(not False)
# Out:
# False
# True

# %%
a = 50
b = 30
print(not False)
print(not (a > b))
# Out:
# True
# False

# %%
# AND operator
val1 = True
val2 = True
print(val1 and val2)
# Out:
# True

# %%
val1 = True
val2 = False                       #any one false = result is false
print("AND operator :",val1 and val2)
# Out:
# AND operator : False

# %%
# OR operator
a = 50                                           #any one True = result is True
b = 30
val1 = True
val2 = False
print("OR operator :", val1 or val2)
# Out:
# OR operator : True

# %%
print("OR operator :", (a == b) or (a > b))
# Out:
# OR operator : True

# %%
val1 = False
val2 = False
print("OR operator :",val1 or val2)
# Out:
# OR operator : False
